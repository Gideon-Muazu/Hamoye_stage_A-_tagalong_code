# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
food_data = pd.read_csv("/Users/hp/Desktop/Gitdoc/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin-1")
food_data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
food_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
food_data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
food_data.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
food_data.groupby('Area')['Y2017','Area'].sum().rank()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6952\2245358014.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   food_data.groupby('Area')['Y2017','Area'].sum().rank()
#                              Y2017
# Area
# Algeria                       43.0
# Angola                        38.0
# Benin                         29.0
# Botswana                       9.0
# Burkina Faso                  26.0
# Cabo Verde                     6.0
# Cameroon                      39.0
# Central African Republic      15.0
# Chad                          21.0
# Comoros                        3.0
# Congo                         16.0
# Côte d'Ivoire                 37.0
# Djibouti                      10.0
# Egypt                         48.0
# Eswatini                      19.0
# Ethiopia                      46.0
# Ethiopia PDR                   1.5
# Gabon                         12.0
# Gambia                        11.0
# ...

# %%
food_data.groupby('Element')['Element','Y2017'].sum()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6952\916319770.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   food_data.groupby('Element')['Element','Y2017'].sum()
#                                              Y2017
# Element
# Domestic supply quantity                2088198.10
# Export Quantity                          182338.80
# Fat supply quantity (g/capita/day)        10253.84
# Feed                                     223705.68
# Food                                    1258888.28
# Food supply (kcal/capita/day)            454681.00
# Food supply quantity (kg/capita/yr)       48690.04
# Import Quantity                          294559.09
# Losses                                   160614.00
# Other uses (non-food)                     91645.97
# Processing                               292836.00
# Production                              2030056.89
# Protein supply quantity (g/capita/day)    11842.45
# ...

# %%
food_data['Area'].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "Côte d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
food_data.groupby('Element')['Element','Y2018','Y2017','Y2016','Y2015','Y2014'].sum()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6952\2047920845.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   food_data.groupby('Element')['Element','Y2018','Y2017','Y2016','Y2015','Y2014'].sum()
#                                              Y2018       Y2017       Y2016  \
# Element
# Domestic supply quantity                2161192.10  2088198.10  2044842.70
# Export Quantity                          181594.80   182338.80   151920.46
# Fat supply quantity (g/capita/day)        10258.69    10253.84    10102.77
# Feed                                     233489.68   223705.68   228958.65
# Food                                    1303841.28  1258888.28  1247022.17
# Food supply (kcal/capita/day)            455261.00   454681.00   451810.00
# Food supply quantity (kg/capita/yr)       49056.85    48690.04    48985.28
# Import Quantity                          287997.09   294559.09   286582.78
# ...

# %%
food_data.groupby('Area')['Area','Y2017'].sum().rank()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6952\289241520.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   food_data.groupby('Area')['Area','Y2017'].sum().rank()
#                              Y2017
# Area
# Algeria                       43.0
# Angola                        38.0
# Benin                         29.0
# Botswana                       9.0
# Burkina Faso                  26.0
# Cabo Verde                     6.0
# Cameroon                      39.0
# Central African Republic      15.0
# Chad                          21.0
# Comoros                        3.0
# Congo                         16.0
# Côte d'Ivoire                 37.0
# Djibouti                      10.0
# Egypt                         48.0
# Eswatini                      19.0
# Ethiopia                      46.0
# Ethiopia PDR                   1.5
# Gabon                         12.0
# Gambia                        11.0
# ...
